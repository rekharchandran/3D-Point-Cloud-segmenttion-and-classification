# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.2

# %%
# %cd "/storage/Projects/notebooks"
# Out:
# /storage/Projects/notebooks

# %%
#!git clone --depth=1 https://github.com/QingyongHu/RandLA-Net && cd RandLA-Net

# %%
# %cd "/storage/Projects/notebooks/RandLA-Net"
# Out:
# /storage/Projects/notebooks/RandLA-Net

# %%
#!pip install -r helper_requirements.txt
# Out:
# /usr/lib/python3/dist-packages/secretstorage/dhcrypto.py:15: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/lib/python3/dist-packages/secretstorage/util.py:19: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
#   Using cached numpy-1.16.1-cp36-cp36m-manylinux1_x86_64.whl (17.3 MB)
# ...
# WARNING: Error parsing requirements for numpy: [Errno 2] No such file or directory: '/usr/local/lib/python3.6/dist-packages/numpy-1.19.5.dist-info/METADATA'
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
# ERROR: Cannot uninstall numpy 1.19.5, RECORD file not found. You might be able to recover from this via: 'pip install --force-reinstall --no-deps numpy==1.19.5'.

# %%
#!sudo -H pip3 install --upgrade PyYAML

# %%
#!pip install six --upgrade --ignore-installed

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# !sh compile_op.sh
# Out:
# running install
# running build
# running build_ext
# skipping 'knn.cpp' Cython extension (up-to-date)
# running install_lib
# running install_egg_info
# Removing ./lib/python/KNN_NanoFLANN-0.0.0.egg-info
# Writing ./lib/python/KNN_NanoFLANN-0.0.0.egg-info
# running build_ext

# %%
#!sh compile_op.sh
# Out:
# running install
# running build
# running build_ext
# cythoning knn.pyx to knn.cpp
# /usr/local/lib/python3.6/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /storage/Projects/notebooks/RandLA-Net/utils/nearest_neighbors/knn.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'nearest_neighbors' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I./ -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c knn.cpp -o build/temp.linux-x86_64-3.6/knn.o -std=c++11 -fopenmp
# In file included from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1822:0,
# ...

# %%
#!sudo apt-get install p7zip-full

# %%
# %cd "/storage/Projects/notebooks/RandLA-Net/utils"
# Out:
# /storage/Projects/notebooks/RandLA-Net/utils

# %%
#/storage/Projects/Fylkesveg/semantic_3d/data/semantic3d/original_data

# %%
#!python3 data_prepare_semantic3d.py
# Out:
# /storage/Projects/Fylkesveg/semantic3d/original_data/sg27_station6_intensity_rgb.txt
# /storage/Projects/Fylkesveg/semantic3d/original_data/sg27_station8_intensity_rgb.txt
# /storage/Projects/Fylkesveg/semantic3d/original_data/bildstein_station1_xyz_intensity_rgb.txt
# /storage/Projects/Fylkesveg/semantic3d/original_data/sg27_station10_intensity_rgb.txt
# /storage/Projects/Fylkesveg/semantic3d/original_data/sg28_Station2_rgb_intensity-reduced.txt
# /storage/Projects/Fylkesveg/semantic3d/original_data/bildstein_station3_xyz_intensity_rgb.txt
# /storage/Projects/Fylkesveg/semantic3d/original_data/sg27_station10_rgb_intensity-reduced.txt
# /storage/Projects/Fylkesveg/semantic3d/original_data/bildstein_station5_xyz_intensity_rgb.txt
# /storage/Projects/Fylkesveg/semantic3d/original_data/castleblatten_station5_xyz_intensity_rgb.txt
# /storage/Projects/Fylkesveg/semantic3d/original_data/StGallenCathedral_station6_rgb_intensity-reduced.txt
# ...

# %%
# !which g++
# !which gcc
# !type make

# %%
from distutils.core import setup
from distutils.extension import Extension
from Cython.Distutils import build_ext
import numpy

# %%
# %cd "/storage/Projects/notebooks/RandLA-Net"
# Out:
# /storage/Projects/notebooks/RandLA-Net

# %%
#!python3 main_Semantic3D.py --mode train --gpu 0
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Load_pc_0: bildstein_station1_xyz_intensity_rgb
# Load_pc_1: bildstein_station5_xyz_intensity_rgb
# Load_pc_2: domfountain_station1_xyz_intensity_rgb
# Load_pc_3: domfountain_station2_xyz_intensity_rgb
# Load_pc_4: domfountain_station3_xyz_intensity_rgb
# Load_pc_5: neugasse_station1_xyz_intensity_rgb
# Load_pc_6: sg27_station1_intensity_rgb
# Load_pc_7: sg27_station4_intensity_rgb
# Load_pc_8: sg27_station5_intensity_rgb
# Load_pc_9: sg27_station9_intensity_rgb
# Load_pc_10: sg28_station4_intensity_rgb
# Load_pc_11: untermaederbrunnen_station1_xyz_intensity_rgb
# Load_pc_12: untermaederbrunnen_station3_xyz_intensity_rgb
# ...

# %%
#!python3 main_Semantic3D.py --mode test --gpu 0
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Load_pc_0: bildstein_station1_xyz_intensity_rgb
# Load_pc_1: bildstein_station5_xyz_intensity_rgb
# Load_pc_2: domfountain_station1_xyz_intensity_rgb
# Load_pc_3: domfountain_station2_xyz_intensity_rgb
# Load_pc_4: domfountain_station3_xyz_intensity_rgb
# Load_pc_5: neugasse_station1_xyz_intensity_rgb
# Load_pc_6: sg27_station1_intensity_rgb
# Load_pc_7: sg27_station4_intensity_rgb
# Load_pc_8: sg27_station5_intensity_rgb
# Load_pc_9: sg27_station9_intensity_rgb
# Load_pc_10: sg28_station4_intensity_rgb
# Load_pc_11: untermaederbrunnen_station1_xyz_intensity_rgb
# Load_pc_12: untermaederbrunnen_station3_xyz_intensity_rgb
# ...

# %%
# !python3 main_Semantic3D.py --mode evaluate --gpu 0
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Load_pc_0: bildstein_station1_xyz_intensity_rgb
# Load_pc_1: bildstein_station5_xyz_intensity_rgb
# Load_pc_2: domfountain_station1_xyz_intensity_rgb
# Load_pc_3: domfountain_station2_xyz_intensity_rgb
# Load_pc_4: domfountain_station3_xyz_intensity_rgb
# Load_pc_5: neugasse_station1_xyz_intensity_rgb
# Load_pc_6: sg27_station1_intensity_rgb
# Load_pc_7: sg27_station4_intensity_rgb
# Load_pc_8: sg27_station5_intensity_rgb
# Load_pc_9: sg27_station9_intensity_rgb
# Load_pc_10: sg28_station4_intensity_rgb
# Load_pc_11: untermaederbrunnen_station1_xyz_intensity_rgb
# Load_pc_12: untermaederbrunnen_station3_xyz_intensity_rgb
# ...

# %%
#visualisation

# %%
# %cd "/storage/Projects/notebooks/RandLA-Net/utils"
# Out:
# /storage/Projects/notebooks/RandLA-Net/utils

# %%
# !python3 6_fold_cv.py
# Out:
# Traceback (most recent call last):
#   File "6_fold_cv.py", line 54, in <module>
#     iou = true_positive_classes[n] / float(gt_classes[n] + positive_classes[n] - true_positive_classes[n])
# ZeroDivisionError: float division by zero

# %%
# python -B main_S3DIS.py --gpu 0 --mode test --test_area 1 --model_path /media/kfr/Elements\ SE/RandLA-Net/RandLA- Net/models/S3DIS/Area_1/snap-260001

# %%
# %cd "/storage/Projects/notebooks/RandLA-Net"
# Out:
# /storage/Projects/notebooks/RandLA-Net

# %%
# !python3 visualize_Semantic3D.py
# Out:
# hey
# hey2

# %%
# !python3 vis_Semantic3D.py

# %%
# !python3 main_Semantic3D.py --mode evaluate --gpu 0
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Load_pc_0: bildstein_station1_xyz_intensity_rgb
# Load_pc_1: bildstein_station5_xyz_intensity_rgb
# Load_pc_2: domfountain_station1_xyz_intensity_rgb
# Load_pc_3: domfountain_station2_xyz_intensity_rgb
# Load_pc_4: domfountain_station3_xyz_intensity_rgb
# Load_pc_5: neugasse_station1_xyz_intensity_rgb
# Load_pc_6: sg27_station1_intensity_rgb
# Load_pc_7: sg27_station4_intensity_rgb
# Load_pc_8: sg27_station5_intensity_rgb
# Load_pc_9: sg27_station9_intensity_rgb
# Load_pc_10: sg28_station4_intensity_rgb
# Load_pc_11: untermaederbrunnen_station1_xyz_intensity_rgb
# Load_pc_12: untermaederbrunnen_station3_xyz_intensity_rgb
# ...

# %%
'/storage/Projects/notebooks/RandLA-Net/test/Log_2022-09-14_13-10-44/predictions/sg28_2-reduced.labels'

# %%
BASE_DIR = os.getcwd()
print(BASE_DIR)
# Out:
# /storage/Projects/notebooks/RandLA-Net

# %%
# !python3 main_Semantic3D.py --gpu 0 --mode vis
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# Load_pc_0: bildstein_station1_xyz_intensity_rgb
# Load_pc_1: bildstein_station5_xyz_intensity_rgb
# Load_pc_2: domfountain_station1_xyz_intensity_rgb
# Load_pc_3: domfountain_station2_xyz_intensity_rgb
# Load_pc_4: domfountain_station3_xyz_intensity_rgb
# Load_pc_5: neugasse_station1_xyz_intensity_rgb
# Load_pc_6: sg27_station1_intensity_rgb
# Load_pc_7: sg27_station4_intensity_rgb
# Load_pc_8: sg27_station5_intensity_rgb
# Load_pc_9: sg27_station9_intensity_rgb
# Load_pc_10: sg28_station4_intensity_rgb
# Load_pc_11: untermaederbrunnen_station1_xyz_intensity_rgb
# Load_pc_12: untermaederbrunnen_station3_xyz_intensity_rgb
# ...

# %%
# !python3 tester_Semantic3D.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# %cd  '/storage/Projects/notebooks/RandLA-Net'
# Out:
# /storage/Projects/notebooks/RandLA-Net

# %%
# !python3 main_Semantic3D.py
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/compat/v2_compat.py:101: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# /storage/Projects/Fylkesveg/semantic3d/input_0.060
# Load_pc_0: bildstein_station1_xyz_intensity_rgb
# Load_pc_1: bildstein_station5_xyz_intensity_rgb
# Load_pc_2: domfountain_station1_xyz_intensity_rgb
# Load_pc_3: domfountain_station2_xyz_intensity_rgb
# Load_pc_4: domfountain_station3_xyz_intensity_rgb
# Load_pc_5: neugasse_station1_xyz_intensity_rgb
# Load_pc_6: sg27_station1_intensity_rgb
# ^C
# Traceback (most recent call last):
#   File "main_Semantic3D.py", line 369, in <module>
#     dataset = Semantic3D()
#   File "main_Semantic3D.py", line 98, in __init__
#     self.load_sub_sampled_clouds(cfg.sub_grid_size)
# ...
